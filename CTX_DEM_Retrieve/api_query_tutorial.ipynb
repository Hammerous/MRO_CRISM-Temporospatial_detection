# %% [markdown]
# **Source: https://stac.astrogeology.usgs.gov/docs/tutorials/advanced_python/**
# In this tutorial we want to use the API to access several databases and then retrieve urls based on a certain critera. For the purposes of this example we will be looking at the incidence angle of each image. Lets start by getting our file set up, for the purposes of this example, we will say we are trying to get images in a certain bounding box.

# %%
from pystac_client import Client
import pandas as pd
import geopandas as gpd
from shapely.geometry import shape
pd.set_option("display.max_colwidth", 150)
import pvl
import aiohttp
import asyncio

# set pystac_client logger to DEBUG to see API calls
import logging
logging.basicConfig()
logger = logging.getLogger('pystac_client') 
logger.setLevel(logging.INFO)

# Bounding Box for this example
bounding_box  = [3,4,5,6]

# Use async to define how to get incidence angle
async def get_incidence(session, url):
    async with session.get(url) as response:
        lbl_as_text = await response.text()
        lbl = pvl.loads(lbl_as_text)
        incidence_angle = lbl['Caminfo']['Geometry']['IncidenceAngle']
        return incidence_angle

loop = asyncio.get_event_loop()

# Setting up the catalog
catalog = Client.open("https://stac.astrogeology.usgs.gov/api/")
print(catalog)
# Out:
# <Client id=usgs-stac-api>

# %% [markdown]
# With this setup code we can then go on to create a geodata frame to store the results of the query. For example, the link to the image, the image id, the geometry, the incidence angle, etc. In the below example, the data is stored in items.gdf

# %%
# Names of the databases you want to retrieve images from
databases = ['kaguya_terrain_camera_stereoscopic_uncontrolled_observations', 'kaguya_terrain_camera_spsupport_uncontrolled_observations', 'kaguya_terrain_camera_monoscopic_uncontrolled_observations']
results = []
result_df = pd.DataFrame()
# Iterate through all the kaguya databases
for database in databases:
    result = catalog.search(collections=[database],bbox=bounding_box, max_items=200)
    results.append(result)

# Get all items as a dictionary
items = []
for r in results:
    items += r.item_collection_as_dict()['features']
for i in items:
    i['geometry'] = shape(i['geometry'])
items_gdf = gpd.GeoDataFrame(pd.json_normalize(items))

# Use async to find the incidence angles
async with aiohttp.ClientSession() as session:
    tasks = []
    for url in items_gdf['assets.caminfo_pvl.href'].values:
        tasks.append(asyncio.ensure_future(get_incidence(session, url)))
    angles = await asyncio.gather(*tasks)

items_gdf['incidence_angle'] = angles
print(items_gdf)
# Out:
#        type stac_version                         id  \
# 0   Feature        1.0.0  TC1W2B0_01_05187N056E0034
# 1   Feature        1.0.0  TC2W2B0_01_05187N061E0034
# 2   Feature        1.0.0  TC1W2B0_01_05187N043E0034
# 3   Feature        1.0.0  TC2W2B0_01_05187N047E0034
# 4   Feature        1.0.0  TC2W2B0_01_05187N034E0035
# ..      ...          ...                        ...
# 65  Feature        1.0.0  TC1S2B0_01_05522N064E0040
# 66  Feature        1.0.0  TC1S2B0_01_05522N050E0040
# 67  Feature        1.0.0  TC1S2B0_01_05522N037E0040
# 68  Feature        1.0.0  TC1S2B0_01_05521N057E0050
# 69  Feature        1.0.0  TC1S2B0_01_05521N043E0050
#
#                                                                                                                                                  geometry  \
# 0   POLYGON ((2.84276 4.853, 2.8417 4.90848, 2.83955 5.04374, 2.83763 5.17901, 2.83614 5.31456, 2.83379 5.44859, 2.83141 5.58266, 2.82948 5.71775, 2.8...
# 1   POLYGON ((2.83876 5.31146, 2.83764 5.36727, 2.83554 5.5026, 2.83348 5.63755, 2.83125 5.77219, 2.82891 5.90648, 2.82677 6.0402, 2.82423 6.17463, 2....
# 2   POLYGON ((2.86552 3.50291, 2.86454 3.55851, 2.8624 3.69393, 2.85984 3.82846, 2.85798 3.9637, 2.85569 4.09791, 2.85336 4.23191, 2.85119 4.3663, 2.8...
# 3   POLYGON ((2.86053 3.96145, 2.85938 4.01725, 2.85685 4.15334, 2.85493 4.28845, 2.85295 4.42325, 2.85047 4.55824, 2.84813 4.69248, 2.84572 4.8266, 2...
# 4   POLYGON ((2.88291 2.6101, 2.88186 2.66567, 2.87986 2.80078, 2.87773 2.93638, 2.8756 3.07184, 2.87352 3.20676, 2.87113 3.34154, 2.86866 3.47597, 2....
# ..                                                                                                                                                    ...
# 65  POLYGON ((3.2575 5.61809, 3.25495 5.7079, 3.25163 5.8506, 3.24964 5.99357, 3.24815 6.1374, 3.24654 6.28191, 3.24551 6.42611, 3.24392 6.57006, 3.24...
# 66  POLYGON ((3.2772 4.28647, 3.27553 4.37559, 3.27593 4.51524, 3.26985 4.66006, 3.26644 4.80402, 3.26487 4.94749, 3.26384 5.09055, 3.26288 5.23352, 3...
# 67  POLYGON ((3.30269 2.9422, 3.30099 3.0327, 3.29681 3.17675, 3.29305 3.32079, 3.28987 3.46507, 3.28733 3.60974, 3.28764 3.75301, 3.291 3.89408, 3.28...
# 68  POLYGON ((4.32187 4.90528, 4.31959 4.99557, 4.31726 5.13793, 4.31406 5.28066, 4.31088 5.42385, 4.30841 5.5679, 4.30625 5.71272, 4.30454 5.85751, 4...
# 69  POLYGON ((4.34385 3.56948, 4.34246 3.65958, 4.34021 3.80207, 4.33748 3.94435, 4.335 4.08659, 4.33229 4.22932, 4.33005 4.37248, 4.32818 4.51624, 4....
#
#                                                                                                                                                     links  \
# 0   [{'rel': 'self', 'type': 'application/geo+json', 'href': 'https://stac.astrogeology.usgs.gov/api//collections/kaguya_terrain_camera_stereoscopic_u...
# 1   [{'rel': 'self', 'type': 'application/geo+json', 'href': 'https://stac.astrogeology.usgs.gov/api//collections/kaguya_terrain_camera_stereoscopic_u...
# 2   [{'rel': 'self', 'type': 'application/geo+json', 'href': 'https://stac.astrogeology.usgs.gov/api//collections/kaguya_terrain_camera_stereoscopic_u...
# 3   [{'rel': 'self', 'type': 'application/geo+json', 'href': 'https://stac.astrogeology.usgs.gov/api//collections/kaguya_terrain_camera_stereoscopic_u...
# 4   [{'rel': 'self', 'type': 'application/geo+json', 'href': 'https://stac.astrogeology.usgs.gov/api//collections/kaguya_terrain_camera_stereoscopic_u...
# ..                                                                                                                                                    ...
# 65  [{'rel': 'self', 'type': 'application/geo+json', 'href': 'https://stac.astrogeology.usgs.gov/api//collections/kaguya_terrain_camera_monoscopic_unc...
# 66  [{'rel': 'self', 'type': 'application/geo+json', 'href': 'https://stac.astrogeology.usgs.gov/api//collections/kaguya_terrain_camera_monoscopic_unc...
# 67  [{'rel': 'self', 'type': 'application/geo+json', 'href': 'https://stac.astrogeology.usgs.gov/api//collections/kaguya_terrain_camera_monoscopic_unc...
# 68  [{'rel': 'self', 'type': 'application/geo+json', 'href': 'https://stac.astrogeology.usgs.gov/api//collections/kaguya_terrain_camera_monoscopic_unc...
# 69  [{'rel': 'self', 'type': 'application/geo+json', 'href': 'https://stac.astrogeology.usgs.gov/api//collections/kaguya_terrain_camera_monoscopic_unc...
#
#                                                                               bbox  \
# 0    [2.8170426452326573, 4.852999323740273, 4.025316317038386, 6.410251021212435]
# 1   [2.8114027418347183, 5.3114577107056204, 4.022103731525804, 6.860404593518424]
# 2    [2.839577953821604, 3.5029052018618736, 4.0465303253029745, 5.05905146169121]
# 3   [2.8355895842844494, 3.958745053861424, 4.038541375299545, 5.5142857265912815]
# 4    [2.8567821694690902, 2.610101106751468, 4.061507381435567, 4.172175632689913]
# ..                                                                             ...
# 65     [3.229001468055295, 5.618090889030949, 4.66300554011589, 7.166136923766608]
# 66     [3.252484765165902, 4.286474703963004, 4.68339021218895, 5.822619859481536]
# 67  [3.276461291662425, 2.9421975653610226, 4.703955106604079, 4.4886398722054945]
# 68     [4.29670136601508, 4.905275000693244, 5.723922837206908, 6.453130327176183]
# 69    [4.3181015182437905, 3.56948274083544, 5.740125840647185, 5.112443770364581]
#
#                                                                                                                                           stac_extensions  \
# 0   [https://stac-extensions.github.io/projection/v1.0.0/schema.json, https://stac-extensions.github.io/datacube/v1.0.0/schema.json, https://stac-exte...
# 1   [https://stac-extensions.github.io/projection/v1.0.0/schema.json, https://stac-extensions.github.io/datacube/v1.0.0/schema.json, https://stac-exte...
# 2   [https://stac-extensions.github.io/projection/v1.0.0/schema.json, https://stac-extensions.github.io/datacube/v1.0.0/schema.json, https://stac-exte...
# 3   [https://stac-extensions.github.io/projection/v1.0.0/schema.json, https://stac-extensions.github.io/datacube/v1.0.0/schema.json, https://stac-exte...
# 4   [https://stac-extensions.github.io/projection/v1.0.0/schema.json, https://stac-extensions.github.io/datacube/v1.0.0/schema.json, https://stac-exte...
# ..                                                                                                                                                    ...
# 65  [https://stac-extensions.github.io/projection/v1.0.0/schema.json, https://stac-extensions.github.io/datacube/v1.0.0/schema.json, https://stac-exte...
# 66  [https://stac-extensions.github.io/projection/v1.0.0/schema.json, https://stac-extensions.github.io/datacube/v1.0.0/schema.json, https://stac-exte...
# 67  [https://stac-extensions.github.io/projection/v1.0.0/schema.json, https://stac-extensions.github.io/datacube/v1.0.0/schema.json, https://stac-exte...
# 68  [https://stac-extensions.github.io/projection/v1.0.0/schema.json, https://stac-extensions.github.io/datacube/v1.0.0/schema.json, https://stac-exte...
# 69  [https://stac-extensions.github.io/projection/v1.0.0/schema.json, https://stac-extensions.github.io/datacube/v1.0.0/schema.json, https://stac-exte...
#
#                                                       collection  \
# 0   kaguya_terrain_camera_stereoscopic_uncontrolled_observations
# 1   kaguya_terrain_camera_stereoscopic_uncontrolled_observations
# 2   kaguya_terrain_camera_stereoscopic_uncontrolled_observations
# 3   kaguya_terrain_camera_stereoscopic_uncontrolled_observations
# 4   kaguya_terrain_camera_stereoscopic_uncontrolled_observations
# ..                                                           ...
# 65    kaguya_terrain_camera_monoscopic_uncontrolled_observations
# 66    kaguya_terrain_camera_monoscopic_uncontrolled_observations
# 67    kaguya_terrain_camera_monoscopic_uncontrolled_observations
# 68    kaguya_terrain_camera_monoscopic_uncontrolled_observations
# 69    kaguya_terrain_camera_monoscopic_uncontrolled_observations
#
#       properties.start_datetime      properties.end_datetime  ...  \
# 0   2008-12-07T06:56:30.618262Z  2008-12-07T06:57:00.882001Z  ...
# 1   2008-12-07T06:56:04.048481Z  2008-12-07T06:56:34.312220Z  ...
# 2   2008-12-07T06:56:04.046480Z  2008-12-07T06:56:34.310219Z  ...
# 3   2008-12-07T06:55:37.476699Z  2008-12-07T06:56:07.740438Z  ...
# 4   2008-12-07T06:55:10.904917Z  2008-12-07T06:55:41.168656Z  ...
# ..                          ...                          ...  ...
# 65  2009-01-03T13:47:06.148673Z  2009-01-03T13:47:36.412161Z  ...
# 66  2009-01-03T13:46:39.577102Z  2009-01-03T13:47:09.840590Z  ...
# 67  2009-01-03T13:46:13.005533Z  2009-01-03T13:46:43.269021Z  ...
# 68  2009-01-03T11:50:24.143002Z  2009-01-03T11:50:54.406489Z  ...
# 69  2009-01-03T11:49:57.571432Z  2009-01-03T11:50:27.834920Z  ...
#
#    assets.pds_label.roles  \
# 0              [metadata]
# 1              [metadata]
# 2              [metadata]
# 3              [metadata]
# 4              [metadata]
# ..                    ...
# 65             [metadata]
# 66             [metadata]
# 67             [metadata]
# 68             [metadata]
# 69             [metadata]
#
#                                                                                                                                   assets.caminfo_pvl.href  \
# 0   https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/stereoscopic/uncontrolled/TC1W2B0_01_05187N056E0034/TC1W2B0_01_05187N05...
# 1   https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/stereoscopic/uncontrolled/TC2W2B0_01_05187N061E0034/TC2W2B0_01_05187N06...
# 2   https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/stereoscopic/uncontrolled/TC1W2B0_01_05187N043E0034/TC1W2B0_01_05187N04...
# 3   https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/stereoscopic/uncontrolled/TC2W2B0_01_05187N047E0034/TC2W2B0_01_05187N04...
# 4   https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/stereoscopic/uncontrolled/TC2W2B0_01_05187N034E0035/TC2W2B0_01_05187N03...
# ..                                                                                                                                                    ...
# 65  https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/monoscopic/uncontrolled/TC1S2B0_01_05522N064E0040/TC1S2B0_01_05522N064E...
# 66  https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/monoscopic/uncontrolled/TC1S2B0_01_05522N050E0040/TC1S2B0_01_05522N050E...
# 67  https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/monoscopic/uncontrolled/TC1S2B0_01_05522N037E0040/TC1S2B0_01_05522N037E...
# 68  https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/monoscopic/uncontrolled/TC1S2B0_01_05521N057E0050/TC1S2B0_01_05521N057E...
# 69  https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/monoscopic/uncontrolled/TC1S2B0_01_05521N043E0050/TC1S2B0_01_05521N043E...
#
#    assets.caminfo_pvl.type assets.caminfo_pvl.title  assets.caminfo_pvl.roles  \
# 0               text/plain           CamInfo Output                [metadata]
# 1               text/plain           CamInfo Output                [metadata]
# 2               text/plain           CamInfo Output                [metadata]
# 3               text/plain           CamInfo Output                [metadata]
# 4               text/plain           CamInfo Output                [metadata]
# ..                     ...                      ...                       ...
# 65              text/plain           CamInfo Output                [metadata]
# 66              text/plain           CamInfo Output                [metadata]
# 67              text/plain           CamInfo Output                [metadata]
# 68              text/plain           CamInfo Output                [metadata]
# 69              text/plain           CamInfo Output                [metadata]
#
#                                                                                                                                   assets.usgscsm_isd.href  \
# 0   https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/stereoscopic/uncontrolled/TC1W2B0_01_05187N056E0034/TC1W2B0_01_05187N05...
# 1   https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/stereoscopic/uncontrolled/TC2W2B0_01_05187N061E0034/TC2W2B0_01_05187N06...
# 2   https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/stereoscopic/uncontrolled/TC1W2B0_01_05187N043E0034/TC1W2B0_01_05187N04...
# 3   https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/stereoscopic/uncontrolled/TC2W2B0_01_05187N047E0034/TC2W2B0_01_05187N04...
# 4   https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/stereoscopic/uncontrolled/TC2W2B0_01_05187N034E0035/TC2W2B0_01_05187N03...
# ..                                                                                                                                                    ...
# 65  https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/monoscopic/uncontrolled/TC1S2B0_01_05522N064E0040/TC1S2B0_01_05522N064E...
# 66  https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/monoscopic/uncontrolled/TC1S2B0_01_05522N050E0040/TC1S2B0_01_05522N050E...
# 67  https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/monoscopic/uncontrolled/TC1S2B0_01_05522N037E0040/TC1S2B0_01_05522N037E...
# 68  https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/monoscopic/uncontrolled/TC1S2B0_01_05521N057E0050/TC1S2B0_01_05521N057E...
# 69  https://astrogeo-ard.s3-us-west-2.amazonaws.com/moon/kaguya/terrain_camera/monoscopic/uncontrolled/TC1S2B0_01_05521N043E0050/TC1S2B0_01_05521N043E...
#
#    assets.usgscsm_isd.type assets.usgscsm_isd.title assets.usgscsm_isd.roles  \
# 0               text/plain              USGSCSM ISD               [metadata]
# 1               text/plain              USGSCSM ISD               [metadata]
# 2               text/plain              USGSCSM ISD               [metadata]
# 3               text/plain              USGSCSM ISD               [metadata]
# 4               text/plain              USGSCSM ISD               [metadata]
# ..                     ...                      ...                      ...
# 65              text/plain              USGSCSM ISD               [metadata]
# 66              text/plain              USGSCSM ISD               [metadata]
# 67              text/plain              USGSCSM ISD               [metadata]
# 68              text/plain              USGSCSM ISD               [metadata]
# 69              text/plain              USGSCSM ISD               [metadata]
#
#    incidence_angle
# 0        62.156197
# 1        62.200894
# 2        62.041003
# 3        62.080773
# 4        61.977305
# ..             ...
# 65       89.651697
# 66       89.618439
# 67       89.584258
# 68       89.568938
# 69       89.533716
#
# [70 rows x 93 columns]

# %% [markdown]
# Now we have all the images that intersect our given bounding box, we want to download them locally. All of these images are hosted on the cloud, so this is a great time to use rclone. First, lets make the paths to were the data is hosted in the cloud

# %%
with open("kaguyatc_images_to_download.txt", 'w') as f:
    for index in range(len(items_gdf)):
        old_url = items_gdf['assets.image.href'].iloc[index]
        updated_url = f"s3_noauth:/{old_url.split('/')[2].split('.')[0]}/{'/'.join(old_url.split('/')[3:])}\n"
        f.write(updated_url)

# %% [markdown]
# Where s3_noauth represents the name where they are stored in your config file. When using rclone one must setup a rclone.conf file. To do this navigate to the rclone.conf file, it should be stored in your home directory in ./.config/rclone/rclone.conf. Open it using vim vim ./.config/rclone/rclone.conf and insert the following in.

# %% [markdown]
# [s3_noauth]
# type = s3
# provider = AWS
# env_auth = false
# region = us-west-2

# %% [markdown]
# Now rclone is all set up and ready to use! Although there are python packages that allow one to use rclone in python, they are a bit clunky and not as well supported. As such it is recommended to create the following script to quickly and easily download your files. Save this script in download_files.sh

# %% [markdown]
# #!/bin/bash
#
# input_file=$1
# destination=$2
#
# while IFS= read -r file; do
#     echo ${file}
#     rclone copy "${file}" "${destination}"
# done < "${input_file}"

# %% [markdown]
# ### .bat form for windows
#
# @echo off
# set input_file=%1
# set destination=%2
#
# for /f "usebackq delims=" %%f in ("%~1") do (
#     echo %%f
#     rclone copy "%%f" "%~2"
# )

# %% [markdown]
# It can then be run with a command like: ```
# bash download_files.sh kaguyatc_images_to_download.txt /path/to/dowload/folder
# ```
#
# Thats it! You have sucesfully downloadde imags using rclone and async. Hopefully this will speed up downloading and fetching processess.
